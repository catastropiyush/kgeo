# %% [markdown]
# <a href="https://colab.research.google.com/github/catastropiyush/kgeo/blob/main/Untitled66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/achael/kgeo.git
# Out:
# Cloning into 'kgeo'...
# remote: Enumerating objects: 534, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 534 (delta 133), reused 142 (delta 109), pack-reused 351 (from 1)
# Receiving objects: 100% (534/534), 2.32 MiB | 18.15 MiB/s, done.
# Resolving deltas: 100% (334/334), done.

# %%
# %cd kgeo
# Out:
# /content/kgeo

# %%
# !pip install .
# Out:
# Processing /content/kgeo
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.8/159.8 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.0/445.0 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.8/466.8 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.5/234.5 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 7.6 MB/s eta 0:00:00
# ...
#   Created wheel for kgeo: filename=kgeo-0.0.1-py3-none-any.whl size=1646948 sha256=d3ec085f5c08655951efe18da276d2978884c109c6f935c45907ba78acdea144
# ...

# %%
from kgeo.kerr_raytracing_ana import *
out = raytrace_ana(plotdata=True)
# Out:
# calculating preliminaries...
# integrating in theta...0.98 s
# integrating in r...1.70 s
# plotting data...
# maxwraps  4
# done!   3.4043591022491455  seconds!
